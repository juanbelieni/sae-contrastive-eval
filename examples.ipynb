# %%
import torch as t
import itertools as it
import polars as pl
import altair as alt
from sae_lens import SAE
from transformer_lens import HookedTransformer
from datasets import load_dataset
from torch.utils.data import DataLoader
from collections import defaultdict

# %%
device = "cuda"
dataset_name = "stas/openwebtext-10k"
transformer_model_name = "gpt2-small"
sae_model_name = "gpt2-small-res-jb"

chunk_size = 20
batch_size = 16

# %%
model = HookedTransformer.from_pretrained(transformer_model_name, device=device)

for params in model.parameters():
    params.requires_grad_(False)
# Out:
# /home/juan/.asdf/installs/python/3.11.9/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Loaded pretrained model gpt2-small into HookedTransformer

# %%
dataset = load_dataset(dataset_name, split='train', trust_remote_code=True)
dataset = dataset.to_list()
dataset = [x["text"] for x in dataset]

# %%
def chunker(iterable, n):
    for i in range(0, len(iterable), n):
        yield iterable[i:i+n]

dataset_chunked = [
    model.tokenizer.decode(chunk)
    for x in dataset[:3]
    for chunk in chunker(model.tokenizer(x, padding=True, truncation=True)["input_ids"], chunk_size)
]

len(dataset_chunked)
# Out:
# 128

# %%
dataloader = DataLoader(dataset_chunked, batch_size=batch_size)

for layer in range(0, 6):
    sae_block_hook = f"blocks.{layer}.hook_resid_pre"

    print(f"Printing examples for block {sae_block_hook}")

    sae, cfg_dict, sparsity = SAE.from_pretrained(
        release=sae_model_name,
        sae_id=sae_block_hook,
        device=device)

    for params in sae.parameters():
        params.requires_grad_(False)

    eos_token_id = model.tokenizer.eos_token_id

    for batch_idx, batch in enumerate(dataloader):
        tokens = model.tokenizer(batch, return_tensors="pt", padding=True, truncation=True)
        token_ids = tokens.input_ids

        logits, cache = model.run_with_cache(token_ids)
        sae_feats = sae.encode(cache[sae_block_hook])
        sae_out = sae.decode(sae_feats)

        n = sae_feats.size(0)

        for i, j in it.product(r := range(n), r):
            if i >= j: continue

            for m, n in it.product(r := range(chunk_size), r):
                # A lot of false positives from EOS tokens
                if eos_token_id in token_ids[i, :m+1] or eos_token_id in token_ids[j, :n+1]:
                    continue

                f_i = sae_feats[i, m]
                f_j = sae_feats[j, n]

                x_i = sae_out[i, m]
                x_j = sae_out[j, n]

                norm_feat = (f_i - f_j).norm(2)
                norm_out = (x_i - x_j).norm(2)

                if 0 < norm_out < 10 and norm_feat > norm_out * 2:
                    str_i = model.tokenizer.decode(token_ids[i, :m+1])
                    str_j = model.tokenizer.decode(token_ids[j, :n+1])

                    print()
                    print(f"{layer = }, {i = }, {j = }")
                    print(f"norm_feats   = {norm_feat.item()}")
                    print(f"norm_out     = {norm_out.item()}")
                    print(f"str_i        = {repr(str_i)}")
                    print(f"str_j        = {repr(str_j)}")
                    print(f"argsort(f_i) = {f_i.argsort()[-5:]}")
                    print(f"argsort(f_j) = {f_j.argsort()[-5:]}")

    del sae
    t.cuda.empty_cache()
# Out:
# Printing examples for block blocks.0.hook_resid_pre
#
# layer = 0, i = 0, j = 10
# norm_feats   = 3.140711784362793
# norm_out     = 1.4815704822540283
# str_i        = 'A magazine supplement with an image of Adolf Hitler and the'
# str_j        = ' tight lid on Hitler’s writings has become a'
# argsort(f_i) = tensor([24182, 18458,  7261, 15603, 17652], device='cuda:0')
# argsort(f_j) = tensor([18458, 24182, 15603, 19064, 11233], device='cuda:0')
#
# layer = 0, i = 2, j = 6
# norm_feats   = 1.9613784551620483
# norm_out     = 0.9013238549232483
# str_i        = ' of Bavaria,'
# str_j        = 't have,'
# argsort(f_i) = tensor([20998, 16482, 15033, 22351, 11916], device='cuda:0')
# argsort(f_j) = tensor([19462, 15033, 22351, 11916,  7292], device='cuda:0')
#
# layer = 0, i = 3, j = 10
# norm_feats   = 3.2950387001037598
# norm_out     = 1.5878008604049683
# str_i        = ')\n\nThe city that was the'
# str_j        = ' tight lid on Hitler’s writings has become a'
# argsort(f_i) = tensor([19064, 15603, 24182, 20998, 17652], device='cuda:0')
# argsort(f_j) = tensor([18458, 24182, 15603, 19064, 11233], device='cuda:0')
#
# layer = 0, i = 4, j = 10
# norm_feats   = 3.0990002155303955
# norm_out     = 1.4949419498443604
# str_i        = ' of the Nazi past, from the bullet holes that pit the'
# str_j        = ' tight lid on Hitler’s writings has become a'
# argsort(f_i) = tensor([ 7550, 18458, 15603,  7261, 17652], device='cuda:0')
# argsort(f_j) = tensor([18458, 24182, 15603, 19064, 11233], device='cuda:0')
#
# layer = 0, i = 5, j = 10
# norm_feats   = 3.185455083847046
# norm_out     = 1.4901267290115356
# str_i        = 'king Luftwaffe headquarters that now house the'
# str_j        = ' tight lid on Hitler’s writings has become a'
# argsort(f_i) = tensor([ 7261, 19064, 24182, 15603, 17652], device='cuda:0')
# argsort(f_j) = tensor([18458, 24182, 15603, 19064, 11233], device='cuda:0')
#
# layer = 0, i = 6, j = 11
# norm_feats   = 1.9613784551620483
# norm_out     = 0.9013238549232483
# str_i        = 't have,'
# str_j        = ' are slowly changing,'
# argsort(f_i) = tensor([19462, 15033, 22351, 11916,  7292], device='cuda:0')
# argsort(f_j) = tensor([20998, 16482, 15033, 22351, 11916], device='cuda:0')
#
# layer = 0, i = 7, j = 12
# norm_feats   = 1.9672569036483765
# norm_out     = 0.9511505961418152
# str_i        = ', “'
# str_j        = ' law bans “'
# argsort(f_i) = tensor([10337, 15033,  7292, 18193, 13353], device='cuda:0')
# argsort(f_j) = tensor([20998, 16482, 15033, 13353, 18193], device='cuda:0')
#
# layer = 0, i = 8, j = 10
# norm_feats   = 3.2950387001037598
# norm_out     = 1.5878008604049683
# str_i        = ' excerpts fizzled this week after the'
# str_j        = ' tight lid on Hitler’s writings has become a'
# argsort(f_i) = tensor([19064, 15603, 24182, 20998, 17652], device='cuda:0')
# argsort(f_j) = tensor([18458, 24182, 15603, 19064, 11233], device='cuda:0')
#
# layer = 0, i = 9, j = 10
# norm_feats   = 3.262983560562134
# norm_out     = 1.5249736309051514
# str_i        = 'ated copy appeared at newspaper kiosks around the'
# str_j        = ' tight lid on Hitler’s writings has become a'
# argsort(f_i) = tensor([19064, 24182, 20998, 15603, 17652], device='cuda:0')
# argsort(f_j) = tensor([18458, 24182, 15603, 19064, 11233], device='cuda:0')
#
# layer = 0, i = 10, j = 15
# norm_feats   = 3.140711784362793
# norm_out     = 1.4815704822540283
# str_i        = ' tight lid on Hitler’s writings has become a'
# str_j        = ', and the book is available in translation elsewhere in the'
# argsort(f_i) = tensor([18458, 24182, 15603, 19064, 11233], device='cuda:0')
# argsort(f_j) = tensor([24182, 18458,  7261, 15603, 17652], device='cuda:0')
#
# layer = 0, i = 0, j = 3
# norm_feats   = 1.9750169515609741
# norm_out     = 0.9395214915275574
# str_i        = ' to publish it'
# str_j        = ' we must ban it'
# argsort(f_i) = tensor([14924,   916, 24150, 15033,  7292], device='cuda:0')
# argsort(f_j) = tensor([20998,   916, 16482, 24150, 15033], device='cuda:0')
#
# layer = 0, i = 1, j = 2
# norm_feats   = 2.9903929233551025
# norm_out     = 1.4850777387619019
# str_i        = ' era, when a complete German-language copy of the book pops up as the'
# str_j        = ' local version of the search engine.\n\n“To say this is a'
# argsort(f_i) = tensor([15603, 14326, 18458,  7261, 17652], device='cuda:0')
# argsort(f_j) = tensor([19064, 15603, 18458, 14326, 11233], device='cuda:0')
#
# layer = 0, i = 1, j = 3
# norm_feats   = 2.995697021484375
# norm_out     = 1.490530252456665
# str_i        = ' era, when a complete German-language copy of the book pops up as the second result on the'
# str_j        = ' we must ban it, this is ridiculous,” said Wolfgang Wippermann, a'
# argsort(f_i) = tensor([20530, 16627, 14326, 17652,  7261], device='cuda:0')
# argsort(f_j) = tensor([20530, 16627, 18458, 14326, 11233], device='cuda:0')
#
# layer = 0, i = 1, j = 11
# norm_feats   = 2.995697021484375
# norm_out     = 1.490530252456665
# str_i        = ' era, when a complete German-language copy of the book pops up as the second result on the'
# str_j        = ' the publicity, had printed two versions of the pamphlet. The version propped on top of a'
# argsort(f_i) = tensor([20530, 16627, 14326, 17652,  7261], device='cuda:0')
# argsort(f_j) = tensor([20530, 16627, 18458, 14326, 11233], device='cuda:0')
#
# layer = 0, i = 1, j = 12
# norm_feats   = 2.995697021484375
# norm_out     = 1.490530252456665
# str_i        = ' era, when a complete German-language copy of the book pops up as the second result on the'
# str_j        = ' of celebrity magazines at a newsstand in Berlin’s central Friedrichstrasse station was a'
# argsort(f_i) = tensor([20530, 16627, 14326, 17652,  7261], device='cuda:0')
# argsort(f_j) = tensor([20530, 16627, 18458, 14326, 11233], device='cuda:0')
#
# layer = 0, i = 2, j = 8
# norm_feats   = 3.014582395553589
# norm_out     = 1.4884506464004517
# str_i        = ' local version of the search engine.\n\n“To say this is a'
# str_j        = ' illegal use of Nazi symbols after the Bavarian government seized reprinted copies of the'
# argsort(f_i) = tensor([19064, 15603, 18458, 14326, 11233], device='cuda:0')
# argsort(f_j) = tensor([15603, 14326, 18458,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 2, j = 10
# norm_feats   = 3.0489628314971924
# norm_out     = 1.5048422813415527
# str_i        = ' local version of the search engine.\n\n“To say this is a'
# str_j        = '� on Thursday was scuttled at the last moment, although the'
# argsort(f_i) = tensor([19064, 15603, 18458, 14326, 11233], device='cuda:0')
# argsort(f_j) = tensor([14326, 15603, 18458,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 3, j = 6
# norm_feats   = 2.995697021484375
# norm_out     = 1.490530252456665
# str_i        = ' we must ban it, this is ridiculous,” said Wolfgang Wippermann, a'
# str_j        = '\n\nThe publisher of the excerpts, London-based Albertus, has said it will appeal the'
# argsort(f_i) = tensor([20530, 16627, 18458, 14326, 11233], device='cuda:0')
# argsort(f_j) = tensor([20530, 16627, 14326, 17652,  7261], device='cuda:0')
#
# layer = 0, i = 3, j = 7
# norm_feats   = 2.995697021484375
# norm_out     = 1.490530252456665
# str_i        = ' we must ban it, this is ridiculous,” said Wolfgang Wippermann, a'
# str_j        = ' Bavarian government’s injunction. In 2009, the publisher beat charges of copyright violation and the'
# argsort(f_i) = tensor([20530, 16627, 18458, 14326, 11233], device='cuda:0')
# argsort(f_j) = tensor([20530, 16627, 14326, 17652,  7261], device='cuda:0')
#
# layer = 0, i = 6, j = 11
# norm_feats   = 2.995697021484375
# norm_out     = 1.490530252456665
# str_i        = '\n\nThe publisher of the excerpts, London-based Albertus, has said it will appeal the'
# str_j        = ' the publicity, had printed two versions of the pamphlet. The version propped on top of a'
# argsort(f_i) = tensor([20530, 16627, 14326, 17652,  7261], device='cuda:0')
# argsort(f_j) = tensor([20530, 16627, 18458, 14326, 11233], device='cuda:0')
#
# layer = 0, i = 6, j = 12
# norm_feats   = 2.995697021484375
# norm_out     = 1.490530252456665
# str_i        = '\n\nThe publisher of the excerpts, London-based Albertus, has said it will appeal the'
# str_j        = ' of celebrity magazines at a newsstand in Berlin’s central Friedrichstrasse station was a'
# argsort(f_i) = tensor([20530, 16627, 14326, 17652,  7261], device='cuda:0')
# argsort(f_j) = tensor([20530, 16627, 18458, 14326, 11233], device='cuda:0')
#
# layer = 0, i = 7, j = 11
# norm_feats   = 2.995697021484375
# norm_out     = 1.490530252456665
# str_i        = ' Bavarian government’s injunction. In 2009, the publisher beat charges of copyright violation and the'
# str_j        = ' the publicity, had printed two versions of the pamphlet. The version propped on top of a'
# argsort(f_i) = tensor([20530, 16627, 14326, 17652,  7261], device='cuda:0')
# argsort(f_j) = tensor([20530, 16627, 18458, 14326, 11233], device='cuda:0')
#
# layer = 0, i = 7, j = 12
# norm_feats   = 2.995697021484375
# norm_out     = 1.490530252456665
# str_i        = ' Bavarian government’s injunction. In 2009, the publisher beat charges of copyright violation and the'
# str_j        = ' of celebrity magazines at a newsstand in Berlin’s central Friedrichstrasse station was a'
# argsort(f_i) = tensor([20530, 16627, 14326, 17652,  7261], device='cuda:0')
# argsort(f_j) = tensor([20530, 16627, 18458, 14326, 11233], device='cuda:0')
#
# layer = 0, i = 1, j = 8
# norm_feats   = 2.995697021484375
# norm_out     = 1.490530252456665
# str_i        = ' of packing it away. This idea is just naive,” said Alexander Luckow, a'
# str_j        = ' not confined to Germany. You look and it’s all around Europe, dating back to the'
# argsort(f_i) = tensor([20530, 16627, 18458, 14326, 11233], device='cuda:0')
# argsort(f_j) = tensor([20530, 16627, 14326, 17652,  7261], device='cuda:0')
#
# layer = 0, i = 2, j = 3
# norm_feats   = 1.9619518518447876
# norm_out     = 0.8993589282035828
# str_i        = ' for the publisher.'
# str_j        = ' German history.'
# argsort(f_i) = tensor([20998, 16482, 15033,  7101, 11916], device='cuda:0')
# argsort(f_j) = tensor([19388, 15033,  7101, 11916,  7292], device='cuda:0')
#
# layer = 0, i = 2, j = 9
# norm_feats   = 1.9619518518447876
# norm_out     = 0.8993589282035828
# str_i        = ' for the publisher.'
# str_j        = ' Middle Ages.'
# argsort(f_i) = tensor([20998, 16482, 15033,  7101, 11916], device='cuda:0')
# argsort(f_j) = tensor([19388, 15033,  7101, 11916,  7292], device='cuda:0')
#
# layer = 0, i = 3, j = 6
# norm_feats   = 1.94447660446167
# norm_out     = 0.8993566036224365
# str_i        = ' German history.�'
# str_j        = ' commentary,�'
# argsort(f_i) = tensor([16482, 22561, 15033, 20857, 10392], device='cuda:0')
# argsort(f_j) = tensor([20857, 15033, 22561,  7292, 10392], device='cuda:0')
#
# layer = 0, i = 6, j = 9
# norm_feats   = 1.94447660446167
# norm_out     = 0.8993566036224365
# str_i        = ' commentary,�'
# str_j        = ' Middle Ages.�'
# argsort(f_i) = tensor([20857, 15033, 22561,  7292, 10392], device='cuda:0')
# argsort(f_j) = tensor([16482, 22561, 15033, 20857, 10392], device='cuda:0')
#
# layer = 0, i = 13, j = 14
# norm_feats   = 3.1061370372772217
# norm_out     = 1.5228351354599
# str_i        = ', and to counter that, they are encouraging a'
# str_j        = '.\n\nGermany’s Jewish organizations have approached the'
# argsort(f_i) = tensor([20998, 24182, 15603, 19064, 11233], device='cuda:0')
# argsort(f_j) = tensor([ 7550, 18458, 15603,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 0, j = 5
# norm_feats   = 3.0489628314971924
# norm_out     = 1.5048422813415527
# str_i        = ' week that found that one in five Germans has anti-Semitic attitudes. And a'
# str_j        = 's voter initiative to legalize pot. If the measure passes, and the'
# argsort(f_i) = tensor([19064, 15603, 18458, 14326, 11233], device='cuda:0')
# argsort(f_j) = tensor([14326, 15603, 18458,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 0, j = 6
# norm_feats   = 3.0489628314971924
# norm_out     = 1.5048422813415527
# str_i        = ' week that found that one in five Germans has anti-Semitic attitudes. And a'
# str_j        = ', many other states will probably be looking at similar law changes in the'
# argsort(f_i) = tensor([19064, 15603, 18458, 14326, 11233], device='cuda:0')
# argsort(f_j) = tensor([14326, 15603, 18458,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 4, j = 5
# norm_feats   = 3.0364432334899902
# norm_out     = 1.4803688526153564
# str_i        = 'For today’s post, I’d like to take a'
# str_j        = 's voter initiative to legalize pot. If the measure passes, and the'
# argsort(f_i) = tensor([15603, 19064, 18458, 14326, 11233], device='cuda:0')
# argsort(f_j) = tensor([14326, 15603, 18458,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 4, j = 6
# norm_feats   = 3.0364432334899902
# norm_out     = 1.4803688526153564
# str_i        = 'For today’s post, I’d like to take a'
# str_j        = ', many other states will probably be looking at similar law changes in the'
# argsort(f_i) = tensor([15603, 19064, 18458, 14326, 11233], device='cuda:0')
# argsort(f_j) = tensor([14326, 15603, 18458,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 4, j = 12
# norm_feats   = 3.1526174545288086
# norm_out     = 1.556059718132019
# str_i        = 'For today’s post, I’d like to take a'
# str_j        = '�s absurd! Think about how expensive that is for the'
# argsort(f_i) = tensor([15603, 19064, 18458, 14326, 11233], device='cuda:0')
# argsort(f_j) = tensor([ 7550, 18458, 15603,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 7, j = 11
# norm_feats   = 1.936202883720398
# norm_out     = 0.9188141226768494
# str_i        = ' of the last'
# str_j        = '. In the last'
# argsort(f_i) = tensor([14924, 10337, 15033,  7292,  2077], device='cuda:0')
# argsort(f_j) = tensor([ 7034, 20998, 16482, 15033,  2077], device='cuda:0')
#
# layer = 0, i = 1, j = 5
# norm_feats   = 3.0766677856445312
# norm_out     = 1.5003087520599365
# str_i        = ' the same rate of tobacco, the'
# str_j        = '17 billion is not exactly a'
# argsort(f_i) = tensor([19064, 24182, 15033, 20998, 17652], device='cuda:0')
# argsort(f_j) = tensor([24182, 19064, 15033, 20998, 11233], device='cuda:0')
#
# layer = 0, i = 4, j = 5
# norm_feats   = 3.1618661880493164
# norm_out     = 1.5789238214492798
# str_i        = ' school education. Or we could use the'
# str_j        = '17 billion is not exactly a'
# argsort(f_i) = tensor([19064, 15603, 24182, 20998, 17652], device='cuda:0')
# argsort(f_j) = tensor([24182, 19064, 15033, 20998, 11233], device='cuda:0')
#
# layer = 0, i = 4, j = 6
# norm_feats   = 3.2950387001037598
# norm_out     = 1.5878008604049683
# str_i        = ' school education. Or we could use the'
# str_j        = ' is to hurt the cartels. Immigration has emerged as a'
# argsort(f_i) = tensor([19064, 15603, 24182, 20998, 17652], device='cuda:0')
# argsort(f_j) = tensor([18458, 24182, 15603, 19064, 11233], device='cuda:0')
#
# layer = 0, i = 5, j = 10
# norm_feats   = 3.1618661880493164
# norm_out     = 1.5789238214492798
# str_i        = '17 billion is not exactly a'
# str_j        = ' countries will always find a way across the'
# argsort(f_i) = tensor([24182, 19064, 15033, 20998, 11233], device='cuda:0')
# argsort(f_j) = tensor([19064, 15603, 24182, 20998, 17652], device='cuda:0')
#
# layer = 0, i = 6, j = 10
# norm_feats   = 3.2950387001037598
# norm_out     = 1.5878008604049683
# str_i        = ' is to hurt the cartels. Immigration has emerged as a'
# str_j        = ' countries will always find a way across the'
# argsort(f_i) = tensor([18458, 24182, 15603, 19064, 11233], device='cuda:0')
# argsort(f_j) = tensor([19064, 15603, 24182, 20998, 17652], device='cuda:0')
#
# layer = 0, i = 0, j = 2
# norm_feats   = 1.9619518518447876
# norm_out     = 0.8993589282035828
# str_i        = ' are charging.'
# str_j        = ' to drug trafficking.'
# argsort(f_i) = tensor([19388, 15033,  7101, 11916,  7292], device='cuda:0')
# argsort(f_j) = tensor([20998, 16482, 15033,  7101, 11916], device='cuda:0')
#
# layer = 0, i = 0, j = 3
# norm_feats   = 2.995697021484375
# norm_out     = 1.490530252456665
# str_i        = ' are charging. Very few people actually want to have to hide their drug use. If given a'
# str_j        = ' have ruined their lives from excess drug use. But it’s not true that marijuana is the'
# argsort(f_i) = tensor([20530, 16627, 18458, 14326, 11233], device='cuda:0')
# argsort(f_j) = tensor([20530, 16627, 14326, 17652,  7261], device='cuda:0')
#
# layer = 0, i = 0, j = 12
# norm_feats   = 2.995697021484375
# norm_out     = 1.490530252456665
# str_i        = ' are charging. Very few people actually want to have to hide their drug use. If given a'
# str_j        = ' being daily terrorised by fascist thugs of the Golden Dawn neonazi party and their local allies in the'
# argsort(f_i) = tensor([20530, 16627, 18458, 14326, 11233], device='cuda:0')
# argsort(f_j) = tensor([20530, 16627, 14326, 17652,  7261], device='cuda:0')
#
# layer = 0, i = 1, j = 5
# norm_feats   = 3.0343759059906006
# norm_out     = 1.4716953039169312
# str_i        = ', marijuana smokers would absolutely buy legal drugs. This would severely weaken the'
# str_j        = ' while doesn’t mean that person will turn around and become a'
# argsort(f_i) = tensor([14326, 15603, 18458,  7261, 17652], device='cuda:0')
# argsort(f_j) = tensor([14326, 18458, 15603, 19064, 11233], device='cuda:0')
#
# layer = 0, i = 3, j = 4
# norm_feats   = 2.9966442584991455
# norm_out     = 1.4879376888275146
# str_i        = ' have ruined their lives from excess drug use. But it’s not true that marijuana is the'
# str_j        = ' gateway drug that people have been demonizing for years. Just because someone smokes pot every once in a'
# argsort(f_i) = tensor([20530, 16627, 14326, 17652,  7261], device='cuda:0')
# argsort(f_j) = tensor([18458, 16627, 20530, 14326, 11233], device='cuda:0')
#
# layer = 0, i = 4, j = 12
# norm_feats   = 2.9966442584991455
# norm_out     = 1.4879376888275146
# str_i        = ' gateway drug that people have been demonizing for years. Just because someone smokes pot every once in a'
# str_j        = ' being daily terrorised by fascist thugs of the Golden Dawn neonazi party and their local allies in the'
# argsort(f_i) = tensor([18458, 16627, 20530, 14326, 11233], device='cuda:0')
# argsort(f_j) = tensor([20530, 16627, 14326, 17652,  7261], device='cuda:0')
#
# layer = 0, i = 5, j = 7
# norm_feats   = 3.1373233795166016
# norm_out     = 1.5125552415847778
# str_i        = ' while doesn’t mean that person will turn around and become a'
# str_j        = ' the law, such as making it illegal to drive under the'
# argsort(f_i) = tensor([14326, 18458, 15603, 19064, 11233], device='cuda:0')
# argsort(f_j) = tensor([ 7550, 18458, 15603,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 5, j = 13
# norm_feats   = 3.0343759059906006
# norm_out     = 1.4716953039169312
# str_i        = ' while doesn’t mean that person will turn around and become a'
# str_j        = ' area of Agios Panteleimonas, moved to unblock the'
# argsort(f_i) = tensor([14326, 18458, 15603, 19064, 11233], device='cuda:0')
# argsort(f_j) = tensor([14326, 15603, 18458,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 6, j = 7
# norm_feats   = 1.9613784551620483
# norm_out     = 0.9013238549232483
# str_i        = ' intoxicates you,'
# str_j        = ' the law,'
# argsort(f_i) = tensor([20998, 16482, 15033, 22351, 11916], device='cuda:0')
# argsort(f_j) = tensor([19462, 15033, 22351, 11916,  7292], device='cuda:0')
#
# layer = 0, i = 0, j = 2
# norm_feats   = 3.307724952697754
# norm_out     = 1.583062767982483
# str_i        = ' attacked by fascists who were soon routed before the'
# str_j        = ' on criminal charges. After the end of the clashes, a'
# argsort(f_i) = tensor([19064, 24182, 20998, 15603, 17652], device='cuda:0')
# argsort(f_j) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
#
# layer = 0, i = 1, j = 2
# norm_feats   = 3.218968629837036
# norm_out     = 1.5237362384796143
# str_i        = ' with the aim of protecting the fascists. During the'
# str_j        = ' on criminal charges. After the end of the clashes, a'
# argsort(f_i) = tensor([ 7261, 19064, 24182, 15603, 17652], device='cuda:0')
# argsort(f_j) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
#
# layer = 0, i = 2, j = 3
# norm_feats   = 3.218968629837036
# norm_out     = 1.5237362384796143
# str_i        = ' on criminal charges. After the end of the clashes, a'
# str_j        = 'as, defying the reign of terror in the'
# argsort(f_i) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
# argsort(f_j) = tensor([ 7261, 19064, 24182, 15603, 17652], device='cuda:0')
#
# layer = 0, i = 2, j = 4
# norm_feats   = 3.1651294231414795
# norm_out     = 1.4930427074432373
# str_i        = ' on criminal charges. After the end of the clashes, a'
# str_j        = ' playground. Soon they were surrounded by fascists who blocked the'
# argsort(f_i) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
# argsort(f_j) = tensor([24182, 18458,  7261, 15603, 17652], device='cuda:0')
#
# layer = 0, i = 2, j = 4
# norm_feats   = 3.0399577617645264
# norm_out     = 1.5196735858917236
# str_i        = ' on criminal charges. After the end of the clashes, a'
# str_j        = ' playground. Soon they were surrounded by fascists who blocked the exit of the'
# argsort(f_i) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
# argsort(f_j) = tensor([14326, 15603, 18458,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 2, j = 5
# norm_feats   = 3.0561444759368896
# norm_out     = 1.490217924118042
# str_i        = ' on criminal charges. After the end of the clashes, a'
# str_j        = ' the father calling him a traitor. After he managed to handle the'
# argsort(f_i) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
# argsort(f_j) = tensor([14326, 18458, 15603,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 2, j = 6
# norm_feats   = 3.307724952697754
# norm_out     = 1.583062767982483
# str_i        = ' on criminal charges. After the end of the clashes, a'
# str_j        = ' fascists beat the father in full presence of the'
# argsort(f_i) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
# argsort(f_j) = tensor([19064, 24182, 20998, 15603, 17652], device='cuda:0')
#
# layer = 0, i = 2, j = 6
# norm_feats   = 3.1141202449798584
# norm_out     = 1.4813807010650635
# str_i        = ' on criminal charges. After the end of the clashes, a'
# str_j        = ' fascists beat the father in full presence of the chief of the'
# argsort(f_i) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
# argsort(f_j) = tensor([ 7550, 18458, 15603,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 2, j = 7
# norm_feats   = 3.0561444759368896
# norm_out     = 1.490217924118042
# str_i        = ' on criminal charges. After the end of the clashes, a'
# str_j        = ' present at the scene then arrested the father and took him to the'
# argsort(f_i) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
# argsort(f_j) = tensor([14326, 18458, 15603,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 2, j = 9
# norm_feats   = 3.1651294231414795
# norm_out     = 1.4930427074432373
# str_i        = ' on criminal charges. After the end of the clashes, a'
# str_j        = ' threatened her life.\n\nThe new tension in the'
# argsort(f_i) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
# argsort(f_j) = tensor([24182, 18458,  7261, 15603, 17652], device='cuda:0')
#
# layer = 0, i = 2, j = 10
# norm_feats   = 3.1141202449798584
# norm_out     = 1.4813807010650635
# str_i        = ' on criminal charges. After the end of the clashes, a'
# str_j        = 'OS, the fascist Popular Orthodox Alarm Party, to the'
# argsort(f_i) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
# argsort(f_j) = tensor([ 7550, 18458, 15603,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 2, j = 13
# norm_feats   = 3.3473949432373047
# norm_out     = 1.6685885190963745
# str_i        = ' on criminal charges. After the end of the clashes, a'
# str_j        = ' immigrants and their greek supporters within the'
# argsort(f_i) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
# argsort(f_j) = tensor([19064, 15603, 24182, 20998, 17652], device='cuda:0')
#
# layer = 0, i = 2, j = 13
# norm_feats   = 3.1141202449798584
# norm_out     = 1.4813807010650635
# str_i        = ' on criminal charges. After the end of the clashes, a'
# str_j        = ' immigrants and their greek supporters within the summer. As the'
# argsort(f_i) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
# argsort(f_j) = tensor([ 7550, 18458, 15603,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 2, j = 15
# norm_feats   = 3.218968629837036
# norm_out     = 1.5237362384796143
# str_i        = ' on criminal charges. After the end of the clashes, a'
# str_j        = ' old military camps of disgraceful humanitarian standards around the'
# argsort(f_i) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
# argsort(f_j) = tensor([ 7261, 19064, 24182, 15603, 17652], device='cuda:0')
#
# layer = 0, i = 2, j = 15
# norm_feats   = 3.0561444759368896
# norm_out     = 1.490217924118042
# str_i        = ' on criminal charges. After the end of the clashes, a'
# str_j        = ' old military camps of disgraceful humanitarian standards around the capital for the'
# argsort(f_i) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
# argsort(f_j) = tensor([14326, 18458, 15603,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 4, j = 5
# norm_feats   = 3.0489628314971924
# norm_out     = 1.5048422813415527
# str_i        = ' playground. Soon they were surrounded by fascists who blocked the exit of the'
# str_j        = ' the father calling him a traitor. After he managed to handle the child to a'
# argsort(f_i) = tensor([14326, 15603, 18458,  7261, 17652], device='cuda:0')
# argsort(f_j) = tensor([19064, 15603, 18458, 14326, 11233], device='cuda:0')
#
# layer = 0, i = 4, j = 12
# norm_feats   = 3.0364432334899902
# norm_out     = 1.4803688526153564
# str_i        = ' playground. Soon they were surrounded by fascists who blocked the exit of the'
# str_j        = ' core of the extreme-right wing policies of LAOS, and pledge a'
# argsort(f_i) = tensor([14326, 15603, 18458,  7261, 17652], device='cuda:0')
# argsort(f_j) = tensor([15603, 19064, 18458, 14326, 11233], device='cuda:0')
#
# layer = 0, i = 5, j = 7
# norm_feats   = 3.086806297302246
# norm_out     = 1.5384634733200073
# str_i        = ' the father calling him a traitor. After he managed to handle the child to a'
# str_j        = ' present at the scene then arrested the father and took him to the'
# argsort(f_i) = tensor([19064, 15603, 18458, 14326, 11233], device='cuda:0')
# argsort(f_j) = tensor([14326, 18458, 15603,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 5, j = 9
# norm_feats   = 3.014582395553589
# norm_out     = 1.4884506464004517
# str_i        = ' the father calling him a traitor. After he managed to handle the child to a'
# str_j        = ' threatened her life.\n\nThe new tension in the area comes after the'
# argsort(f_i) = tensor([19064, 15603, 18458, 14326, 11233], device='cuda:0')
# argsort(f_j) = tensor([15603, 14326, 18458,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 5, j = 11
# norm_feats   = 2.9903929233551025
# norm_out     = 1.4850777387619019
# str_i        = ' the father calling him a traitor. After he managed to handle the child to a'
# str_j        = " vote. This in combination with the governing party's landslide defeat, has led the"
# argsort(f_i) = tensor([19064, 15603, 18458, 14326, 11233], device='cuda:0')
# argsort(f_j) = tensor([15603, 14326, 18458,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 5, j = 12
# norm_feats   = 3.0703678131103516
# norm_out     = 1.4996166229248047
# str_i        = ' the father calling him a traitor. After he managed to handle the'
# str_j        = ' core of the extreme-right wing policies of LAOS, and pledge a'
# argsort(f_i) = tensor([14326, 18458, 15603,  7261, 17652], device='cuda:0')
# argsort(f_j) = tensor([15603, 19064, 18458, 14326, 11233], device='cuda:0')
#
# layer = 0, i = 5, j = 14
# norm_feats   = 2.9903929233551025
# norm_out     = 1.4850777387619019
# str_i        = ' the father calling him a traitor. After he managed to handle the child to a'
# str_j        = ' old NATO airbase of Aspropyrgos is now deemed impractical, the'
# argsort(f_i) = tensor([19064, 15603, 18458, 14326, 11233], device='cuda:0')
# argsort(f_j) = tensor([15603, 14326, 18458,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 5, j = 15
# norm_feats   = 3.086806297302246
# norm_out     = 1.5384634733200073
# str_i        = ' the father calling him a traitor. After he managed to handle the child to a'
# str_j        = ' old military camps of disgraceful humanitarian standards around the capital for the'
# argsort(f_i) = tensor([19064, 15603, 18458, 14326, 11233], device='cuda:0')
# argsort(f_j) = tensor([14326, 18458, 15603,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 6, j = 12
# norm_feats   = 3.1526174545288086
# norm_out     = 1.556059718132019
# str_i        = ' fascists beat the father in full presence of the chief of the'
# str_j        = ' core of the extreme-right wing policies of LAOS, and pledge a'
# argsort(f_i) = tensor([ 7550, 18458, 15603,  7261, 17652], device='cuda:0')
# argsort(f_j) = tensor([15603, 19064, 18458, 14326, 11233], device='cuda:0')
#
# layer = 0, i = 7, j = 12
# norm_feats   = 3.0703678131103516
# norm_out     = 1.4996166229248047
# str_i        = ' present at the scene then arrested the father and took him to the'
# str_j        = ' core of the extreme-right wing policies of LAOS, and pledge a'
# argsort(f_i) = tensor([14326, 18458, 15603,  7261, 17652], device='cuda:0')
# argsort(f_j) = tensor([15603, 19064, 18458, 14326, 11233], device='cuda:0')
#
# layer = 0, i = 9, j = 12
# norm_feats   = 3.0059735774993896
# norm_out     = 1.4768832921981812
# str_i        = ' threatened her life.\n\nThe new tension in the area comes after the'
# str_j        = ' core of the extreme-right wing policies of LAOS, and pledge a'
# argsort(f_i) = tensor([15603, 14326, 18458,  7261, 17652], device='cuda:0')
# argsort(f_j) = tensor([15603, 19064, 18458, 14326, 11233], device='cuda:0')
#
# layer = 0, i = 10, j = 12
# norm_feats   = 3.1526174545288086
# norm_out     = 1.556059718132019
# str_i        = 'OS, the fascist Popular Orthodox Alarm Party, to the'
# str_j        = ' core of the extreme-right wing policies of LAOS, and pledge a'
# argsort(f_i) = tensor([ 7550, 18458, 15603,  7261, 17652], device='cuda:0')
# argsort(f_j) = tensor([15603, 19064, 18458, 14326, 11233], device='cuda:0')
#
# layer = 0, i = 11, j = 12
# norm_feats   = 2.983879804611206
# norm_out     = 1.485074520111084
# str_i        = " vote. This in combination with the governing party's landslide defeat, has led the"
# str_j        = ' core of the extreme-right wing policies of LAOS, and pledge a'
# argsort(f_i) = tensor([15603, 14326, 18458,  7261, 17652], device='cuda:0')
# argsort(f_j) = tensor([15603, 19064, 18458, 14326, 11233], device='cuda:0')
#
# layer = 0, i = 12, j = 13
# norm_feats   = 3.1526174545288086
# norm_out     = 1.556059718132019
# str_i        = ' core of the extreme-right wing policies of LAOS, and pledge a'
# str_j        = ' immigrants and their greek supporters within the summer. As the'
# argsort(f_i) = tensor([15603, 19064, 18458, 14326, 11233], device='cuda:0')
# argsort(f_j) = tensor([ 7550, 18458, 15603,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 12, j = 14
# norm_feats   = 2.983879804611206
# norm_out     = 1.485074520111084
# str_i        = ' core of the extreme-right wing policies of LAOS, and pledge a'
# str_j        = ' old NATO airbase of Aspropyrgos is now deemed impractical, the'
# argsort(f_i) = tensor([15603, 19064, 18458, 14326, 11233], device='cuda:0')
# argsort(f_j) = tensor([15603, 14326, 18458,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 12, j = 15
# norm_feats   = 3.0703678131103516
# norm_out     = 1.4996166229248047
# str_i        = ' core of the extreme-right wing policies of LAOS, and pledge a'
# str_j        = ' old military camps of disgraceful humanitarian standards around the capital for the'
# argsort(f_i) = tensor([15603, 19064, 18458, 14326, 11233], device='cuda:0')
# argsort(f_j) = tensor([14326, 18458, 15603,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 0, j = 1
# norm_feats   = 2.9903929233551025
# norm_out     = 1.4850777387619019
# str_i        = ' of foreigners". The measures and discourse comes as little surprise as it comes from a'
# str_j        = ' wanting to displace homosexuals in desert islands in the late 1970s. Furthermore the'
# argsort(f_i) = tensor([19064, 15603, 18458, 14326, 11233], device='cuda:0')
# argsort(f_j) = tensor([15603, 14326, 18458,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 0, j = 5
# norm_feats   = 3.014582395553589
# norm_out     = 1.4884506464004517
# str_i        = ' of foreigners". The measures and discourse comes as little surprise as it comes from a'
# str_j        = ' of a disputed legislation that would eventually render protest marches illegal. Due to the'
# argsort(f_i) = tensor([19064, 15603, 18458, 14326, 11233], device='cuda:0')
# argsort(f_j) = tensor([15603, 14326, 18458,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 0, j = 6
# norm_feats   = 2.9903929233551025
# norm_out     = 1.4850777387619019
# str_i        = ' of foreigners". The measures and discourse comes as little surprise as it comes from a'
# str_j        = ' by one MP, the government has resorted to yet another legal trick by increasing the'
# argsort(f_i) = tensor([19064, 15603, 18458, 14326, 11233], device='cuda:0')
# argsort(f_j) = tensor([15603, 14326, 18458,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 0, j = 7
# norm_feats   = 3.086806297302246
# norm_out     = 1.5384634733200073
# str_i        = ' of foreigners". The measures and discourse comes as little surprise as it comes from a'
# str_j        = ' by one, non-elected member of its own liking for the'
# argsort(f_i) = tensor([19064, 15603, 18458, 14326, 11233], device='cuda:0')
# argsort(f_j) = tensor([14326, 18458, 15603,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 0, j = 11
# norm_feats   = 3.086806297302246
# norm_out     = 1.5384634733200073
# str_i        = ' of foreigners". The measures and discourse comes as little surprise as it comes from a'
# str_j        = ' by the ruling class were destroyed. At the same time, the'
# argsort(f_i) = tensor([19064, 15603, 18458, 14326, 11233], device='cuda:0')
# argsort(f_j) = tensor([14326, 18458, 15603,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 1, j = 2
# norm_feats   = 3.218968629837036
# norm_out     = 1.5237362384796143
# str_i        = ' wanting to displace homosexuals in desert islands in the'
# str_j        = '" operation of the coming summer is said to also include a'
# argsort(f_i) = tensor([ 7261, 19064, 24182, 15603, 17652], device='cuda:0')
# argsort(f_j) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
#
# layer = 0, i = 1, j = 3
# norm_feats   = 3.133850336074829
# norm_out     = 1.5249406099319458
# str_i        = ' wanting to displace homosexuals in desert islands in the'
# str_j        = ' actions to immigrants by the movement as a'
# argsort(f_i) = tensor([ 7261, 19064, 24182, 15603, 17652], device='cuda:0')
# argsort(f_j) = tensor([15603, 24182, 19064, 20998, 11233], device='cuda:0')
#
# layer = 0, i = 1, j = 10
# norm_feats   = 3.218968629837036
# norm_out     = 1.5237362384796143
# str_i        = ' wanting to displace homosexuals in desert islands in the'
# str_j        = ' tax office was bombed by a Marxist guerrilla group, while a'
# argsort(f_i) = tensor([ 7261, 19064, 24182, 15603, 17652], device='cuda:0')
# argsort(f_j) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
#
# layer = 0, i = 2, j = 3
# norm_feats   = 3.1141202449798584
# norm_out     = 1.4813807010650635
# str_i        = '" operation of the coming summer is said to also include a'
# str_j        = ' actions to immigrants by the movement as a whole. This the'
# argsort(f_i) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
# argsort(f_j) = tensor([ 7550, 18458, 15603,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 2, j = 4
# norm_feats   = 1.9780807495117188
# norm_out     = 0.8882449865341187
# str_i        = '" operation of the'
# str_j        = ' occupation of the'
# argsort(f_i) = tensor([ 1143, 20998, 16482, 15033, 17652], device='cuda:0')
# argsort(f_j) = tensor([14924,  1143, 15033, 17652,  7292], device='cuda:0')
#
# layer = 0, i = 2, j = 4
# norm_feats   = 3.3473949432373047
# norm_out     = 1.6685885190963745
# str_i        = '" operation of the coming summer is said to also include a'
# str_j        = ' occupation of the center of Athens for the'
# argsort(f_i) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
# argsort(f_j) = tensor([19064, 15603, 24182, 20998, 17652], device='cuda:0')
#
# layer = 0, i = 2, j = 7
# norm_feats   = 3.0561444759368896
# norm_out     = 1.490217924118042
# str_i        = '" operation of the coming summer is said to also include a'
# str_j        = ' by one, non-elected member of its own liking for the'
# argsort(f_i) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
# argsort(f_j) = tensor([14326, 18458, 15603,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 2, j = 8
# norm_feats   = 3.1141202449798584
# norm_out     = 1.4813807010650635
# str_i        = '" operation of the coming summer is said to also include a'
# str_j        = '\nThe dictatorial rule of the right-wing and the'
# argsort(f_i) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
# argsort(f_j) = tensor([ 7550, 18458, 15603,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 2, j = 9
# norm_feats   = 1.9780807495117188
# norm_out     = 0.8882449865341187
# str_i        = '" operation of the'
# str_j        = ' is increasing the'
# argsort(f_i) = tensor([ 1143, 20998, 16482, 15033, 17652], device='cuda:0')
# argsort(f_j) = tensor([14924,  1143, 15033, 17652,  7292], device='cuda:0')
#
# layer = 0, i = 2, j = 11
# norm_feats   = 3.307724952697754
# norm_out     = 1.583062767982483
# str_i        = '" operation of the coming summer is said to also include a'
# str_j        = ' by the ruling class were destroyed. At the'
# argsort(f_i) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
# argsort(f_j) = tensor([19064, 24182, 20998, 15603, 17652], device='cuda:0')
#
# layer = 0, i = 2, j = 11
# norm_feats   = 3.0561444759368896
# norm_out     = 1.490217924118042
# str_i        = '" operation of the coming summer is said to also include a'
# str_j        = ' by the ruling class were destroyed. At the same time, the'
# argsort(f_i) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
# argsort(f_j) = tensor([14326, 18458, 15603,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 2, j = 13
# norm_feats   = 3.307724952697754
# norm_out     = 1.583062767982483
# str_i        = '" operation of the coming summer is said to also include a'
# str_j        = ' well as in expectation of an evacuation of the'
# argsort(f_i) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
# argsort(f_j) = tensor([19064, 24182, 20998, 15603, 17652], device='cuda:0')
#
# layer = 0, i = 2, j = 14
# norm_feats   = 3.3473949432373047
# norm_out     = 1.6685885190963745
# str_i        = '" operation of the coming summer is said to also include a'
# str_j        = ' immigrants and are a constant target by the'
# argsort(f_i) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
# argsort(f_j) = tensor([19064, 15603, 24182, 20998, 17652], device='cuda:0')
#
# layer = 0, i = 3, j = 4
# norm_feats   = 3.155724287033081
# norm_out     = 1.4435259103775024
# str_i        = ' actions to immigrants by the movement as a'
# str_j        = ' occupation of the center of Athens for the'
# argsort(f_i) = tensor([15603, 24182, 19064, 20998, 11233], device='cuda:0')
# argsort(f_j) = tensor([19064, 15603, 24182, 20998, 17652], device='cuda:0')
#
# layer = 0, i = 3, j = 8
# norm_feats   = 3.1404411792755127
# norm_out     = 1.4746760129928589
# str_i        = ' actions to immigrants by the movement as a'
# str_j        = '\nThe dictatorial rule of the'
# argsort(f_i) = tensor([15603, 24182, 19064, 20998, 11233], device='cuda:0')
# argsort(f_j) = tensor([19064, 24182, 15033, 20998, 17652], device='cuda:0')
#
# layer = 0, i = 3, j = 9
# norm_feats   = 3.137181520462036
# norm_out     = 1.5493170022964478
# str_i        = ' actions to immigrants by the movement as a'
# str_j        = ' is increasing the tension across the'
# argsort(f_i) = tensor([15603, 24182, 19064, 20998, 11233], device='cuda:0')
# argsort(f_j) = tensor([  513, 24182, 20998, 15033, 17652], device='cuda:0')
#
# layer = 0, i = 3, j = 10
# norm_feats   = 3.1141202449798584
# norm_out     = 1.4813807010650635
# str_i        = ' actions to immigrants by the movement as a whole. This the'
# str_j        = ' tax office was bombed by a Marxist guerrilla group, while a'
# argsort(f_i) = tensor([ 7550, 18458, 15603,  7261, 17652], device='cuda:0')
# argsort(f_j) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
#
# layer = 0, i = 3, j = 11
# norm_feats   = 3.169949531555176
# norm_out     = 1.4741629362106323
# str_i        = ' actions to immigrants by the movement as a'
# str_j        = ' by the ruling class were destroyed. At the'
# argsort(f_i) = tensor([15603, 24182, 19064, 20998, 11233], device='cuda:0')
# argsort(f_j) = tensor([19064, 24182, 20998, 15603, 17652], device='cuda:0')
#
# layer = 0, i = 3, j = 13
# norm_feats   = 3.169949531555176
# norm_out     = 1.4741629362106323
# str_i        = ' actions to immigrants by the movement as a'
# str_j        = ' well as in expectation of an evacuation of the'
# argsort(f_i) = tensor([15603, 24182, 19064, 20998, 11233], device='cuda:0')
# argsort(f_j) = tensor([19064, 24182, 20998, 15603, 17652], device='cuda:0')
#
# layer = 0, i = 3, j = 14
# norm_feats   = 3.155724287033081
# norm_out     = 1.4435259103775024
# str_i        = ' actions to immigrants by the movement as a'
# str_j        = ' immigrants and are a constant target by the'
# argsort(f_i) = tensor([15603, 24182, 19064, 20998, 11233], device='cuda:0')
# argsort(f_j) = tensor([19064, 15603, 24182, 20998, 17652], device='cuda:0')
#
# layer = 0, i = 4, j = 10
# norm_feats   = 3.1618661880493164
# norm_out     = 1.5789238214492798
# str_i        = ' occupation of the center of Athens for the'
# str_j        = ' tax office was bombed by a'
# argsort(f_i) = tensor([19064, 15603, 24182, 20998, 17652], device='cuda:0')
# argsort(f_j) = tensor([24182, 19064, 15033, 20998, 11233], device='cuda:0')
#
# layer = 0, i = 4, j = 10
# norm_feats   = 3.3473949432373047
# norm_out     = 1.6685885190963745
# str_i        = ' occupation of the center of Athens for the'
# str_j        = ' tax office was bombed by a Marxist guerrilla group, while a'
# argsort(f_i) = tensor([19064, 15603, 24182, 20998, 17652], device='cuda:0')
# argsort(f_j) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
#
# layer = 0, i = 6, j = 7
# norm_feats   = 1.9613784551620483
# norm_out     = 0.9013238549232483
# str_i        = ' by one MP,'
# str_j        = ' by one,'
# argsort(f_i) = tensor([20998, 16482, 15033, 22351, 11916], device='cuda:0')
# argsort(f_j) = tensor([19462, 15033, 22351, 11916,  7292], device='cuda:0')
#
# layer = 0, i = 7, j = 10
# norm_feats   = 3.0561444759368896
# norm_out     = 1.490217924118042
# str_i        = ' by one, non-elected member of its own liking for the'
# str_j        = ' tax office was bombed by a Marxist guerrilla group, while a'
# argsort(f_i) = tensor([14326, 18458, 15603,  7261, 17652], device='cuda:0')
# argsort(f_j) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
#
# layer = 0, i = 8, j = 10
# norm_feats   = 3.0766677856445312
# norm_out     = 1.5003087520599365
# str_i        = '\nThe dictatorial rule of the'
# str_j        = ' tax office was bombed by a'
# argsort(f_i) = tensor([19064, 24182, 15033, 20998, 17652], device='cuda:0')
# argsort(f_j) = tensor([24182, 19064, 15033, 20998, 11233], device='cuda:0')
#
# layer = 0, i = 8, j = 10
# norm_feats   = 3.1141202449798584
# norm_out     = 1.4813807010650635
# str_i        = '\nThe dictatorial rule of the right-wing and the'
# str_j        = ' tax office was bombed by a Marxist guerrilla group, while a'
# argsort(f_i) = tensor([ 7550, 18458, 15603,  7261, 17652], device='cuda:0')
# argsort(f_j) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
#
# layer = 0, i = 9, j = 10
# norm_feats   = 2.9893510341644287
# norm_out     = 1.4607592821121216
# str_i        = ' is increasing the tension across the'
# str_j        = ' tax office was bombed by a'
# argsort(f_i) = tensor([  513, 24182, 20998, 15033, 17652], device='cuda:0')
# argsort(f_j) = tensor([24182, 19064, 15033, 20998, 11233], device='cuda:0')
#
# layer = 0, i = 10, j = 11
# norm_feats   = 3.307724952697754
# norm_out     = 1.583062767982483
# str_i        = ' tax office was bombed by a Marxist guerrilla group, while a'
# str_j        = ' by the ruling class were destroyed. At the'
# argsort(f_i) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
# argsort(f_j) = tensor([19064, 24182, 20998, 15603, 17652], device='cuda:0')
#
# layer = 0, i = 10, j = 11
# norm_feats   = 3.0561444759368896
# norm_out     = 1.490217924118042
# str_i        = ' tax office was bombed by a Marxist guerrilla group, while a'
# str_j        = ' by the ruling class were destroyed. At the same time, the'
# argsort(f_i) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
# argsort(f_j) = tensor([14326, 18458, 15603,  7261, 17652], device='cuda:0')
#
# layer = 0, i = 10, j = 13
# norm_feats   = 3.307724952697754
# norm_out     = 1.583062767982483
# str_i        = ' tax office was bombed by a Marxist guerrilla group, while a'
# str_j        = ' well as in expectation of an evacuation of the'
# argsort(f_i) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
# argsort(f_j) = tensor([19064, 24182, 20998, 15603, 17652], device='cuda:0')
#
# layer = 0, i = 10, j = 14
# norm_feats   = 3.1618661880493164
# norm_out     = 1.5789238214492798
# str_i        = ' tax office was bombed by a'
# str_j        = ' immigrants and are a constant target by the'
# argsort(f_i) = tensor([24182, 19064, 15033, 20998, 11233], device='cuda:0')
# argsort(f_j) = tensor([19064, 15603, 24182, 20998, 17652], device='cuda:0')
#
# layer = 0, i = 10, j = 14
# norm_feats   = 3.3473949432373047
# norm_out     = 1.6685885190963745
# str_i        = ' tax office was bombed by a Marxist guerrilla group, while a'
# str_j        = ' immigrants and are a constant target by the'
# argsort(f_i) = tensor([24182, 18458, 15603, 19064, 11233], device='cuda:0')
# argsort(f_j) = tensor([19064, 15603, 24182, 20998, 17652], device='cuda:0')
# Printing examples for block blocks.1.hook_resid_pre
#
# layer = 1, i = 3, j = 5
# norm_feats   = 14.172483444213867
# norm_out     = 5.540523052215576
# str_i        = ')\n\nThe city that was the center of Adolf Hitler’'
# str_j        = 'king Luftwaffe headquarters that now house the Finance Ministry.\n\nWhat it doesn’'
# argsort(f_i) = tensor([22119, 24387, 21958, 15135,  3945], device='cuda:0')
# argsort(f_j) = tensor([ 1380,   344, 22119,  3945, 15135], device='cuda:0')
#
# layer = 1, i = 5, j = 6
# norm_feats   = 11.45981502532959
# norm_out     = 4.474911212921143
# str_i        = 'king Luftwaffe headquarters that now house the Finance Ministry.\n\nWhat it doesn’'
# str_j        = 't have, nor has it since 1945, are copies of Hitler’'
# argsort(f_i) = tensor([ 1380,   344, 22119,  3945, 15135], device='cuda:0')
# argsort(f_j) = tensor([22119, 24387, 21958, 15135,  3945], device='cuda:0')
#
# layer = 1, i = 5, j = 15
# norm_feats   = 13.238395690917969
# norm_out     = 6.481009006500244
# str_i        = ' it’s over, it makes no sense. You can find it so easily.”'
# str_j        = '-era newspapers.\n\n“Mein Kampf”'
# argsort(f_i) = tensor([10115,   344, 22119, 16723, 13403], device='cuda:0')
# argsort(f_j) = tensor([ 9487, 22119, 21958, 13403, 16723], device='cuda:0')
#
# layer = 1, i = 1, j = 8
# norm_feats   = 3.573272466659546
# norm_out     = 1.4466720819473267
# str_i        = ' of packing it away. This idea is just naive,�'
# str_j        = ' not confined to Germany. You look and it�'
# argsort(f_i) = tensor([21958,  5017, 17917,  7354,  5363], device='cuda:0')
# argsort(f_j) = tensor([21958, 17917,  5017,  7354,  5363], device='cuda:0')
#
# layer = 1, i = 1, j = 10
# norm_feats   = 9.506599426269531
# norm_out     = 4.363594055175781
# str_i        = ' of packing it away. This idea is just naive,�'
# str_j        = ' make it to newsstands. German law extends copyright 70 years after the author�'
# argsort(f_i) = tensor([21958,  5017, 17917,  7354,  5363], device='cuda:0')
# argsort(f_j) = tensor([ 4878, 19386,  7354, 17917,  5363], device='cuda:0')
#
# layer = 1, i = 1, j = 14
# norm_feats   = 19.791223526000977
# norm_out     = 8.291325569152832
# str_i        = ' of packing it away. This idea is just naive,�'
# str_j        = '.\n\nGermany�'
# ...
# argsort(f_i) = tensor([14380,   262, 24020,  6977,  2016], device='cuda:0')
# argsort(f_j) = tensor([12658,  1378, 24020,  2016,  6977], device='cuda:0')
#
# layer = 2, i = 3, j = 6
# norm_feats   = 6.95910120010376
# norm_out     = 2.8180267810821533
# str_i        = ')\n\nThe city that was the center of Adolf Hitler�'
# str_j        = 't have, nor has it since 1945, are copies of Hitler�'
# argsort(f_i) = tensor([14380,   262, 24020,  6977,  2016], device='cuda:0')
# argsort(f_j) = tensor([ 9813,  1229, 24020,  6977,  2016], device='cuda:0')
#
# layer = 2, i = 3, j = 6
# norm_feats   = 4.486843585968018
# norm_out     = 2.166486978530884
# str_i        = ')\n\nThe city that was the center of Adolf Hitler’'
# str_j        = 't have, nor has it since 1945, are copies of Hitler’'
# argsort(f_i) = tensor([  750,  1231, 22841, 18471, 12756], device='cuda:0')
# argsort(f_j) = tensor([15420,  1231,  4430, 18471, 12756], device='cuda:0')
#
# layer = 2, i = 3, j = 10
# norm_feats   = 16.50251007080078
# norm_out     = 7.338294982910156
# str_i        = ')\n\nThe city that was the center of Adolf Hitler�'
# str_j        = ' tight lid on Hitler�'
# argsort(f_i) = tensor([14380,   262, 24020,  6977,  2016], device='cuda:0')
# argsort(f_j) = tensor([ 9813, 14380,   262,  1229,  2016], device='cuda:0')
#
# layer = 2, i = 3, j = 10
# norm_feats   = 18.597572326660156
# norm_out     = 7.6008710861206055
# str_i        = ')\n\nThe city that was the center of Adolf Hitler’'
# str_j        = ' tight lid on Hitler’'
# argsort(f_i) = tensor([  750,  1231, 22841, 18471, 12756], device='cuda:0')
# argsort(f_j) = tensor([ 4430,  1697,  1231, 12756, 18471], device='cuda:0')
#
# layer = 2, i = 6, j = 10
# norm_feats   = 20.245115280151367
# norm_out     = 8.95970630645752
# str_i        = 't have, nor has it since 1945, are copies of Hitler�'
# str_j        = ' tight lid on Hitler�'
# argsort(f_i) = tensor([ 9813,  1229, 24020,  6977,  2016], device='cuda:0')
# argsort(f_j) = tensor([ 9813, 14380,   262,  1229,  2016], device='cuda:0')
#
# layer = 2, i = 6, j = 10
# norm_feats   = 21.75354766845703
# norm_out     = 8.78342056274414
# str_i        = 't have, nor has it since 1945, are copies of Hitler’'
# str_j        = ' tight lid on Hitler’'
# argsort(f_i) = tensor([15420,  1231,  4430, 18471, 12756], device='cuda:0')
# argsort(f_j) = tensor([ 4430,  1697,  1231, 12756, 18471], device='cuda:0')
#
# layer = 2, i = 2, j = 15
# norm_feats   = 5.054389953613281
# norm_out     = 2.005476713180542
# str_i        = ' local version of the search engine.\n\n�'
# str_j        = '-era newspapers.\n\n�'
# argsort(f_i) = tensor([14468, 24020,  6977, 12658,  2016], device='cuda:0')
# argsort(f_j) = tensor([ 9813, 24020,  6977, 12658,  2016], device='cuda:0')
#
# layer = 2, i = 2, j = 15
# norm_feats   = 6.204822540283203
# norm_out     = 2.6070492267608643
# str_i        = ' local version of the search engine.\n\n“'
# str_j        = '-era newspapers.\n\n“'
# argsort(f_i) = tensor([ 2682, 14468, 12622, 11916,  1189], device='cuda:0')
# argsort(f_j) = tensor([ 5834, 14468, 12622,  1189, 11916], device='cuda:0')
#
# layer = 2, i = 5, j = 14
# norm_feats   = 13.602383613586426
# norm_out     = 6.409806251525879
# str_i        = ' it’s over,'
# str_j        = ' text stamped with “Unreadable” in the other,'
# argsort(f_i) = tensor([ 1483,  7769,  9715,  9510, 19742], device='cuda:0')
# argsort(f_j) = tensor([19481,  1483, 12841, 19742,  9510], device='cuda:0')
#
# layer = 2, i = 7, j = 12
# norm_feats   = 17.726716995239258
# norm_out     = 6.952880859375
# str_i        = ' Bavarian government’'
# str_j        = ' of celebrity magazines at a newsstand in Berlin’'
# argsort(f_i) = tensor([ 4430,  1231, 22841, 12756, 18471], device='cuda:0')
# argsort(f_j) = tensor([  750,  4430,  1231, 12756, 18471], device='cuda:0')
#
# layer = 2, i = 0, j = 4
# norm_feats   = 17.292692184448242
# norm_out     = 6.626619338989258
# str_i        = ', and the whole thinking is absolutely not'
# str_j        = '�s words as inspiration, not'
# argsort(f_i) = tensor([14807, 15404, 12749, 21434, 11741], device='cuda:0')
# argsort(f_j) = tensor([12749,  6328, 15404, 23422, 21434], device='cuda:0')
#
# layer = 2, i = 1, j = 3
# norm_feats   = 19.551719665527344
# norm_out     = 7.922247886657715
# str_i        = ' of packing it away. This idea is just naive,”'
# str_j        = ' German history.”'
# argsort(f_i) = tensor([23422,   352, 15420, 17486,  3694], device='cuda:0')
# argsort(f_j) = tensor([  352, 15678,  7672,  3694, 17486], device='cuda:0')
#
# layer = 2, i = 1, j = 6
# norm_feats   = 25.17045021057129
# norm_out     = 9.658914566040039
# str_i        = ' of packing it away. This idea is just naive,”'
# str_j        = ' commentary,”'
# argsort(f_i) = tensor([23422,   352, 15420, 17486,  3694], device='cuda:0')
# argsort(f_j) = tensor([15678, 22372, 16199,  3694, 17486], device='cuda:0')
#
# layer = 2, i = 1, j = 9
# norm_feats   = 19.927112579345703
# norm_out     = 7.8540849685668945
# str_i        = ' of packing it away. This idea is just naive,”'
# str_j        = ' Middle Ages.”'
# argsort(f_i) = tensor([23422,   352, 15420, 17486,  3694], device='cuda:0')
# argsort(f_j) = tensor([  352, 15678,  7672,  3694, 17486], device='cuda:0')
#
# layer = 2, i = 2, j = 6
# norm_feats   = 12.931550979614258
# norm_out     = 4.623328685760498
# str_i        = ' for the publisher. “'
# str_j        = ' commentary,” he said. “'
# argsort(f_i) = tensor([ 7672, 20883, 11965,  1189, 11916], device='cuda:0')
# argsort(f_j) = tensor([  352,  7672, 20883,  1189, 11916], device='cuda:0')
#
# layer = 2, i = 3, j = 8
# norm_feats   = 15.868585586547852
# norm_out     = 7.8774333000183105
# str_i        = ' German history.�'
# str_j        = ' not confined to Germany. You look and it�'
# argsort(f_i) = tensor([14380,   262, 12235, 11997,  2016], device='cuda:0')
# argsort(f_j) = tensor([14380,  1378, 24020,  6977,  2016], device='cuda:0')
#
# layer = 2, i = 3, j = 14
# norm_feats   = 9.230072021484375
# norm_out     = 4.086766242980957
# str_i        = ' German history.�'
# str_j        = '.\n\nGermany�'
# argsort(f_i) = tensor([14380,   262, 12235, 11997,  2016], device='cuda:0')
# argsort(f_j) = tensor([  262, 24020, 12235, 12658,  2016], device='cuda:0')
#
# layer = 2, i = 6, j = 11
# norm_feats   = 20.239789962768555
# norm_out     = 8.702155113220215
# str_i        = ' commentary,”'
# str_j        = '; after 2015, “Mein Kampf”'
# argsort(f_i) = tensor([15678, 22372, 16199,  3694, 17486], device='cuda:0')
# argsort(f_j) = tensor([15420,   270, 21634, 17486,  3694], device='cuda:0')
#
# layer = 2, i = 6, j = 11
# norm_feats   = 12.535834312438965
# norm_out     = 5.324495315551758
# str_i        = ' commentary,” he said. “'
# str_j        = '; after 2015, “'
# argsort(f_i) = tensor([  352,  7672, 20883,  1189, 11916], device='cuda:0')
# argsort(f_j) = tensor([23422, 20883, 11965,  1189, 11916], device='cuda:0')
#
# layer = 2, i = 6, j = 14
# norm_feats   = 22.21084976196289
# norm_out     = 9.049705505371094
# str_i        = ' commentary,” he said. “This is forbidden and it’'
# str_j        = '.\n\nGermany’'
# argsort(f_i) = tensor([15420,  1231, 24170, 18471, 12756], device='cuda:0')
# argsort(f_j) = tensor([ 1231, 14468, 22841, 12756, 18471], device='cuda:0')
#
# layer = 2, i = 8, j = 10
# norm_feats   = 14.97530746459961
# norm_out     = 6.6180267333984375
# str_i        = ' not confined to Germany. You look and it�'
# str_j        = ' make it to newsstands. German law extends copyright 70 years after the author�'
# argsort(f_i) = tensor([14380,  1378, 24020,  6977,  2016], device='cuda:0')
# argsort(f_j) = tensor([  262,  1229, 24020,  6977,  2016], device='cuda:0')
#
# layer = 2, i = 8, j = 10
# norm_feats   = 12.675806999206543
# norm_out     = 6.2733330726623535
# str_i        = ' not confined to Germany. You look and it’'
# str_j        = ' make it to newsstands. German law extends copyright 70 years after the author’'
# argsort(f_i) = tensor([ 5910, 15887,  1231, 12756, 18471], device='cuda:0')
# argsort(f_j) = tensor([22841, 15420,  4430, 18471, 12756], device='cuda:0')
#
# layer = 2, i = 8, j = 14
# norm_feats   = 13.859732627868652
# norm_out     = 4.910211563110352
# str_i        = ' not confined to Germany. You look and it’'
# str_j        = '.\n\nGermany’'
# argsort(f_i) = tensor([ 5910, 15887,  1231, 12756, 18471], device='cuda:0')
# argsort(f_j) = tensor([ 1231, 14468, 22841, 12756, 18471], device='cuda:0')
#
# layer = 2, i = 4, j = 5
# norm_feats   = 19.640533447265625
# norm_out     = 8.958861351013184
# str_i        = 'For today’s post, I’'
# str_j        = 's voter initiative to legalize pot. If the measure passes, and the sky doesn’'
# argsort(f_i) = tensor([19160, 17088, 11692, 12756, 18471], device='cuda:0')
# argsort(f_j) = tensor([ 6099, 15420,  4430, 18471, 12756], device='cuda:0')
#
# layer = 2, i = 4, j = 7
# norm_feats   = 22.767683029174805
# norm_out     = 9.995199203491211
# str_i        = 'For today’'
# str_j        = ' of the last century has simply not worked, and it’'
# argsort(f_i) = tensor([ 5834, 22372, 13558, 12756, 18471], device='cuda:0')
# argsort(f_j) = tensor([11083,  4430,  1231, 12756, 18471], device='cuda:0')
#
# layer = 2, i = 5, j = 7
# norm_feats   = 11.931015014648438
# norm_out     = 5.935540676116943
# str_i        = 's voter initiative to legalize pot. If the measure passes, and the sky doesn’'
# str_j        = ' of the last century has simply not worked, and it’'
# argsort(f_i) = tensor([ 6099, 15420,  4430, 18471, 12756], device='cuda:0')
# argsort(f_j) = tensor([11083,  4430,  1231, 12756, 18471], device='cuda:0')
#
# layer = 2, i = 7, j = 15
# norm_feats   = 22.15598487854004
# norm_out     = 9.846963882446289
# str_i        = ' of the last century has simply not worked, and it’'
# str_j        = ', it’'
# argsort(f_i) = tensor([11083,  4430,  1231, 12756, 18471], device='cuda:0')
# argsort(f_j) = tensor([ 4430, 21855,  1231, 12756, 18471], device='cuda:0')
#
# layer = 2, i = 8, j = 14
# norm_feats   = 24.54871940612793
# norm_out     = 9.625958442687988
# str_i        = ' attempting to legalize marijuana.\n\nThe statistics on marijuana arrests are really'
# str_j        = ' student in the Oakland school system. It seems to me that if you really'
# argsort(f_i) = tensor([15420, 14468, 15404,   566, 10417], device='cuda:0')
# argsort(f_j) = tensor([15630, 15404, 15420, 10417,  1906], device='cuda:0')
#
# layer = 2, i = 2, j = 3
# norm_feats   = 10.676568031311035
# norm_out     = 4.069401264190674
# str_i        = ' to drug trafficking.\n\nI’'
# str_j        = ' have ruined their lives from excess drug use. But it’'
# argsort(f_i) = tensor([19160, 10658, 14468, 12756, 18471], device='cuda:0')
# argsort(f_j) = tensor([14468,  7672,  1231, 18471, 12756], device='cuda:0')
#
# layer = 2, i = 5, j = 9
# norm_feats   = 15.739175796508789
# norm_out     = 7.646389484405518
# str_i        = ' the father calling him a traitor. After he managed to handle the child to a sympathetic neighbor, the'
# str_j        = ' threatened her life.\n\nThe new tension in the'
# argsort(f_i) = tensor([11692, 23422,  5643, 23165, 17688], device='cuda:0')
# argsort(f_j) = tensor([20679,  2765, 14468, 12266, 17688], device='cuda:0')
#
# layer = 2, i = 11, j = 14
# norm_feats   = 28.971643447875977
# norm_out     = 9.846247673034668
# str_i        = ' by the ruling class were destroyed. At the same time'
# str_j        = ' immigrants and are a constant target by the bourgeois media who waste no time'
# argsort(f_i) = tensor([14909, 15887, 21566,  8539, 23102], device='cuda:0')
# argsort(f_j) = tensor([15732, 10502, 15887, 15420,  8539], device='cuda:0')
# Printing examples for block blocks.3.hook_resid_pre
#
# layer = 3, i = 3, j = 14
# norm_feats   = 16.787824630737305
# norm_out     = 8.342644691467285
# str_i        = ' we must ban it, this is ridiculous,”'
# str_j        = ' text stamped with “Unreadable”'
# argsort(f_i) = tensor([18679, 10564,  1251, 11712, 12103], device='cuda:0')
# argsort(f_j) = tensor([ 1251,  7854, 12199, 23039, 12103], device='cuda:0')
#
# layer = 3, i = 3, j = 15
# norm_feats   = 18.563907623291016
# norm_out     = 8.502866744995117
# str_i        = ' we must ban it, this is ridiculous,”'
# str_j        = '-era newspapers.\n\n“Mein Kampf”'
# argsort(f_i) = tensor([18679, 10564,  1251, 11712, 12103], device='cuda:0')
# argsort(f_j) = tensor([20943,  1251, 12199, 23039, 12103], device='cuda:0')
#
# layer = 3, i = 4, j = 9
# norm_feats   = 20.37636947631836
# norm_out     = 7.667343616485596
# str_i        = ' of modern history at the Free University of Berlin. “'
# str_j        = ' in-house newspaper.\n\nThe attempt to publish portions of “'
# argsort(f_i) = tensor([21533,  1251, 21125,  7413, 10769], device='cuda:0')
# argsort(f_j) = tensor([ 4912,  2790,  1251, 21125, 10769], device='cuda:0')
#
# layer = 3, i = 1, j = 3
# norm_feats   = 21.327306747436523
# norm_out     = 9.286823272705078
# str_i        = ' of packing it away. This idea is just naive,”'
# str_j        = ' German history.”'
# argsort(f_i) = tensor([ 7854, 10564,  1251, 11712, 12103], device='cuda:0')
# argsort(f_j) = tensor([ 7568,  3911,  1565,  2425, 12103], device='cuda:0')
#
# layer = 3, i = 1, j = 11
# norm_feats   = 18.561723709106445
# norm_out     = 8.311984062194824
# str_i        = ' of packing it away. This idea is just naive,”'
# str_j        = '; after 2015, “Mein Kampf”'
# argsort(f_i) = tensor([ 7854, 10564,  1251, 11712, 12103], device='cuda:0')
# argsort(f_j) = tensor([12199, 20943,  1251, 23039, 12103], device='cuda:0')
#
# layer = 3, i = 2, j = 11
# norm_feats   = 12.637709617614746
# norm_out     = 6.265108108520508
# str_i        = ' for the publisher. “'
# str_j        = '; after 2015, “'
# argsort(f_i) = tensor([ 1565, 21125,  9048,  7413, 10769], device='cuda:0')
# argsort(f_j) = tensor([ 1528, 10564,  7413, 21125, 10769], device='cuda:0')
#
# layer = 3, i = 3, j = 6
# norm_feats   = 17.933319091796875
# norm_out     = 7.512391567230225
# str_i        = ' German history.”'
# str_j        = ' commentary,”'
# argsort(f_i) = tensor([ 7568,  3911,  1565,  2425, 12103], device='cuda:0')
# argsort(f_j) = tensor([22578, 12212, 19018, 11712, 12103], device='cuda:0')
#
# layer = 3, i = 6, j = 9
# norm_feats   = 16.570438385009766
# norm_out     = 7.922176837921143
# str_i        = ' commentary,”'
# str_j        = ' Middle Ages.”'
# argsort(f_i) = tensor([22578, 12212, 19018, 11712, 12103], device='cuda:0')
# argsort(f_j) = tensor([14100, 12212,  9555,  2425, 12103], device='cuda:0')
#
# layer = 3, i = 8, j = 10
# norm_feats   = 12.593552589416504
# norm_out     = 5.901743412017822
# str_i        = ' not confined to Germany. You look and it’'
# str_j        = ' make it to newsstands. German law extends copyright 70 years after the author’'
# argsort(f_i) = tensor([10499,  1446,  1251,  7565,  3911], device='cuda:0')
# argsort(f_j) = tensor([24455,  7565,  1251,  1446,  3911], device='cuda:0')
#
# layer = 3, i = 7, j = 11
# norm_feats   = 19.270797729492188
# norm_out     = 9.56436538696289
# str_i        = ' draconian immigration law and many similar propositions being considered by'
# str_j        = ' so high that increased patrols by'
# argsort(f_i) = tensor([12514, 15585, 21533,  4271, 11850], device='cuda:0')
# argsort(f_j) = tensor([11850, 15048, 22244, 22144,  4271], device='cuda:0')
# Printing examples for block blocks.4.hook_resid_pre
#
# layer = 4, i = 9, j = 15
# norm_feats   = 13.861682891845703
# norm_out     = 6.280282974243164
# str_i        = 'ated copy appeared at newspaper kiosks around the country.\n\nBut'
# str_j        = ', and the book is available in translation elsewhere in the world.\n\nBut'
# argsort(f_i) = tensor([15798,  3534, 24475, 13692, 10610], device='cuda:0')
# argsort(f_j) = tensor([ 3534, 13692, 24475,  7949, 10610], device='cuda:0')
#
# layer = 4, i = 3, j = 6
# norm_feats   = 21.6693058013916
# norm_out     = 9.49370288848877
# str_i        = ' German history.”'
# str_j        = ' commentary,”'
# argsort(f_i) = tensor([15984,  6989, 16892,  3500, 13491], device='cuda:0')
# argsort(f_j) = tensor([ 8501, 16892,  3500, 10726, 13491], device='cuda:0')
#
# layer = 4, i = 6, j = 9
# norm_feats   = 20.036325454711914
# norm_out     = 9.179635047912598
# str_i        = ' commentary,”'
# str_j        = ' Middle Ages.”'
# argsort(f_i) = tensor([ 8501, 16892,  3500, 10726, 13491], device='cuda:0')
# argsort(f_j) = tensor([14783, 15984, 16892,  3500, 13491], device='cuda:0')
# Printing examples for block blocks.5.hook_resid_pre
